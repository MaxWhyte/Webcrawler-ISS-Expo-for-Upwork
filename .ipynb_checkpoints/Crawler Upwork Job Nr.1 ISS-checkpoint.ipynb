# %%
#get company name from mainpage
def get_company_name(soup):
    content_company_name = []
    for link in soup.find_all("a", {"class":"exhibitorName"}):
        text = link.get_text()
        text = text.strip()
        content_company_name.append(text)
    return content_company_name

# %%
#find all internal links from mainpage
def get_link(soup):
    links = []
    for link in soup.find_all("a", {"class":"exhibitorName"}):
            text = link.get("href")
            text = text.strip()
            links.append(text)
    return links

# %%
#get booth number from mainpage
def get_booth(soup):
    content_booth = []
    for link in soup.find_all("a", {"class":"boothLabel aa-mapIt"}):
        text = link.get_text()
        text = text.strip()
        content_booth.append(text)
    return content_booth

# %%
#get external url from each individual company page
def get_website(soup):
    if soup.find_all("a", {"class":"aa-BoothContactUrl"}):
        for link in soup.find_all("a", {"class":"aa-BoothContactUrl"}):
            text = link.get_text()
            text = text.strip()
    else:
        text = "No Website"
    return text

# %%
get_website(soup)
# Out:
# 'No Website'

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><title>
# 	2020 Impressions Expo Long Beach
# </title><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="//libs.a2zinc.net/assets/release/bs/css/bootstrap.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/bs/css/bootstrap-colorselector.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/bs/css/datepicker.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/bs-touch-carousel/dist/css/bootstrap-touch-carousel.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/bs-sweetalert/sweet-alert.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/fa/css/font-awesome.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/show/css/site.css?v=20.2.2" rel="stylesheet"/>
# ...

# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import re

# %%
url = "https://iss.a2zinc.net/LongBeach2020/Public/exhibitors.aspx?ID=20972" # url to scrape
payload = {'api_key': '62a2d2f1df797ef728682435edac78c0', 'url': #using external API to circumvent blocking and captchas
url}
r = requests.get('http://api.scraperapi.com', params=payload) #scraping the mainpage

# %%
soup = BeautifulSoup(r.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><title>
# 	2020 Impressions Expo Long Beach: Exhibitors
# </title><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="//libs.a2zinc.net/assets/release/bs/css/bootstrap.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/bs/css/bootstrap-colorselector.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/bs/css/datepicker.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/bs-touch-carousel/dist/css/bootstrap-touch-carousel.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/bs-sweetalert/sweet-alert.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/fa/css/font-awesome.css?v=20.2.2" rel="stylesheet"/>
# <link href="//libs.a2zinc.net/assets/release/show/css/site.css?v=20.2.2" rel="stylesheet"/>
# ...

# %%
#checking length of all items, should be equal count
print(len(get_company_name(soup)))
print(len(get_link(soup)))
print(len(get_booth(soup)))
# Out:
# 316
# 316
# 316

# %%
df = pd.DataFrame() # creating empty DF

# %%
df["Company_Name"] = get_company_name(soup)

# %%
df["Internal_link"] = get_link(soup)
df["Link"] = "https://iss.a2zinc.net/LongBeach2020/Public/" + df["Internal_link"]
df = df.drop("Internal_link", axis=1)

# %%
df["Booth"] = get_booth(soup)

# %%
internal_links = df["Link"].tolist()

# %%
websites = []

for link in internal_links: # scraping each individual link in internal links list
    url = link
    payload = {'api_key': '62a2d2f1df797ef728682435edac78c0', 'url': url}
    time.sleep(1)
    r = requests.get('http://api.scraperapi.com', params=payload)
    soup = BeautifulSoup(r.content, 'html.parser')
    websites.append(get_website(soup))

# %%
len(websites)
# Out:
# 316

# %%
df["Website"] = websites

# %%
#safe as csv
df.to_csv("ISS expo info.csv")

# %%
#reopen csv to create DF again with first column as index
df = pd.read_csv("ISS expo info.csv", index_col=0)

# %%
df.head(10)
# Out:
#                            Company_Name  \
# 0                        Awkward Styles
# 1                     Big Oven Tees Inc
# 2                    3A Thread & Supply
# 3  A&E Robison-Anton Embroidery Threads
# 4                   A.K.H., S. de R. L.
# 5                                A.M.S.
# 6                             A4 Moshay
# 7                              AA Mills
# 8             Ace Transfer Company Inc.
# 9                    Action Illustrated
#
#                                                 Link Booth  \
# 0  https://iss.a2zinc.net/LongBeach2020/Public/eB...   257
# 1  https://iss.a2zinc.net/LongBeach2020/Public/eB...  4033
# 2  https://iss.a2zinc.net/LongBeach2020/Public/eB...  2525
# 3  https://iss.a2zinc.net/LongBeach2020/Public/eB...   830
# 4  https://iss.a2zinc.net/LongBeach2020/Public/eB...  1310
# 5  https://iss.a2zinc.net/LongBeach2020/Public/eB...   764
# 6  https://iss.a2zinc.net/LongBeach2020/Public/eB...  1659
# ...

# %%
#find email addresses on individual websites
#url = "http://www.amefird.com/contact/contact-us/"
urls = df.iloc[0:10, 3]
email_list = []

for url in urls:
    print("Parsing ", url)
    try:
        r = requests.get(url)
        soup = BeautifulSoup(r.content, 'html.parser')
        emails = re.findall(r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,4}",str(soup))
        email_list.append(emails[0])
        email_dump = append(emails)
        print("Mail: ", email)
        
    except:
        email_list.append("No Email")
        print("No Mail")
        
#HIER: todo: add alernatives for contact pages, route via api to prevent blocking

# %%
email_list
# Out:
# ['support@b2c.awkwardstyles.com',
#  'info@bigoventees.com',
#  'No Email',
#  'No Email',
#  'No Email',
#  'email@example.com',
#  'No Email',
#  'No Email',
#  'No Email',
#  'No Email']

# %%
urls = df.iloc[0:10, 3]

# %%
urls
# Out:
# 0      http://www.awkwardstyles.com
# 1        http://www.bigoventees.com
# 2               http://www.us3a.com
# 3            http://www.amefird.com
# 4                        No Website
# 5    http://www.amsfashionhouse.com
# 6                 http://www.a4.com
# 7                   www.aamills.com
# 8         http://www.acetransco.com
# 9                        No Website
# Name: Website, dtype: object

# %%
for x in urls:
    print(x)
# Out:
# http://www.awkwardstyles.com
# http://www.bigoventees.com
# http://www.us3a.com
# http://www.amefird.com
# No Website
# http://www.amsfashionhouse.com
# http://www.a4.com
# www.aamills.com
# http://www.acetransco.com
# No Website

# %%
emails2
# Out:
# ['sales@elevatetextiles.com',
#  'sales@elevatetextiles.com',
#  'jacob.blackburn@amefird.com']
